# %% [markdown]
# <a href="https://colab.research.google.com/github/Innovatewithapple/keras/blob/main/mnistcnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers import Dense,Conv2D,MaxPool2D,Flatten,Input
from keras.utils import to_categorical
from keras.datasets import mnist

import numpy as np
from sklearn.metrics import classification_report

# %%
(x_train,y_train),(x_test,y_test) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
# we reshape because CNN requires 4D (batchsize,height,width,channels)
x_train = x_train.reshape(-1,28,28,1).astype('float32')
x_test = x_test.reshape(-1,28,28,1).astype('float32')

# %%
#normalization
x_train = x_train / 255
x_test = x_test / 255

# %%
num_classes = len(np.unique(y_train))
num_classes
# Out:
# 10

# %%
#categorise
y_train = to_categorical(y_train,num_classes)
y_test = to_categorical(y_test,num_classes)

# %%
model = Sequential()
model.add(Input(shape=(28,28,1)))
model.add(Conv2D(16,kernel_size=(5,5),strides=(2,2),activation='relu'))
model.add(MaxPool2D((2,2),strides=(1,1)))
model.add(Flatten())
model.add(Dense(num_classes,activation='softmax'))

model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

model.fit(x_train,y_train,batch_size=50,epochs=80,verbose=2,validation_split=0.2)
# Out:
# Epoch 1/80
# 960/960 - 17s - 17ms/step - accuracy: 0.9156 - loss: 0.2898 - val_accuracy: 0.9643 - val_loss: 0.1210
# Epoch 2/80
# 960/960 - 19s - 20ms/step - accuracy: 0.9713 - loss: 0.0985 - val_accuracy: 0.9745 - val_loss: 0.0879
# Epoch 3/80
# 960/960 - 10s - 11ms/step - accuracy: 0.9782 - loss: 0.0729 - val_accuracy: 0.9789 - val_loss: 0.0697
# Epoch 4/80
# 960/960 - 11s - 11ms/step - accuracy: 0.9827 - loss: 0.0578 - val_accuracy: 0.9812 - val_loss: 0.0637
# Epoch 5/80
# 960/960 - 9s - 9ms/step - accuracy: 0.9847 - loss: 0.0497 - val_accuracy: 0.9818 - val_loss: 0.0599
# Epoch 6/80
# 960/960 - 10s - 10ms/step - accuracy: 0.9870 - loss: 0.0436 - val_accuracy: 0.9822 - val_loss: 0.0608
# Epoch 7/80
# 960/960 - 10s - 10ms/step - accuracy: 0.9886 - loss: 0.0378 - val_accuracy: 0.9841 - val_loss: 0.0549
# Epoch 8/80
# 960/960 - 10s - 10ms/step - accuracy: 0.9894 - loss: 0.0343 - val_accuracy: 0.9837 - val_loss: 0.0555
# Epoch 9/80
# ...
